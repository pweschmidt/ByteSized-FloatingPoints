# %%
# Floating Point Exercises for the ByteSized dRTP class on 26 March 2026
# The code will be added during the class
# You may download it at your leasure afterwards

# %%
print(0.1 + 0.2 == 0.3)
# Out:
# False

# %%
print(0.1 + 0.2)
# Out:
# 0.30000000000000004

# %%
from decimal import Decimal

# %%
Decimal(0.1 + 0.2)
# Out:
# Decimal('0.3000000000000000444089209850062616169452667236328125')

# %%
import math

# %%
pi = math.pi
lohschmidt = 6.022e23

# %%
a = (lohschmidt + pi) - lohschmidt

# %%
print(a == pi)
# Out:
# False

# %%
print(a)
# Out:
# 0.0

# %%
term1 = pi + lohschmidt - lohschmidt
term2 = lohschmidt - lohschmidt + pi

# %%
print(term1 == term2)
# Out:
# False

# %%
print(term1)
# Out:
# 0.0

# %%
print(term2)
# Out:
# 3.141592653589793

# %%
sum = 0.0
for _ in range(200):
    sum += 0.1
print(sum == 20.0)
Decimal(sum)
# Out:
# False
# Decimal('20.0000000000000142108547152020037174224853515625')

# %%
print(Decimal (math.fsum( [0.1] * 200) ) )
# Out:
# 20
